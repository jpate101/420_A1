# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import csr_matrix
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
import itertools
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import KMeans
import helper
# %matplotlib inline

# %%
# Import the Movies dataset
movies = pd.read_csv('data/Q1/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Import the ratings dataset
ratings = pd.read_csv('data/Q1/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# Print the number of records and the total number of movies
print('The dataset contains: ', len(ratings), ' ratings of ', len(movies), ' movies.')
# Out:
# The dataset contains:  100836  ratings of  9742  movies.

# %%
#Mvoiew level clustering

# %%
# Merge the two tables then pivot so we have Users X Movies dataframe
ratings_title = pd.merge(ratings, movies[['movieId', 'title']], on='movieId' )
user_movie_ratings = pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')
print('dataset dimensions: ', user_movie_ratings.shape, '\n\nSubset example:')
user_movie_ratings.iloc[:6, :10]
# Out:
# dataset dimensions:  (610, 9719)
#
# Subset example:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# 6              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
# 6                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
# 6                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)
# userId
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN

# %%
n_movies = 30
n_users = 18
most_rated_movies_users_selection = helper.sort_by_rating_density(user_movie_ratings, n_movies, n_users)

print('dataset dimensions: ', most_rated_movies_users_selection.shape)
most_rated_movies_users_selection.head()
# Out:
# dataset dimensions:  (18, 30)
# title  Forrest Gump (1994)  Shawshank Redemption, The (1994)  \
# 413                    5.0                               5.0
# 589                    5.0                               4.5
# 473                    3.0                               5.0
# 479                    5.0                               5.0
# 67                     3.5                               3.0
#
# title  Pulp Fiction (1994)  Silence of the Lambs, The (1991)  \
# 413                    5.0                               4.0
# 589                    4.5                               3.5
# 473                    4.0                               4.5
# 479                    4.0                               4.5
# 67                     2.0                               3.5
#
# title  Matrix, The (1999)  Star Wars: Episode IV - A New Hope (1977)  \
# 413                   5.0                                        5.0
# 589                   4.0                                        5.0
# 473                   4.5                                        4.0
# 479                   5.0                                        4.5
# 67                    4.5                                        5.0
#
# title  Jurassic Park (1993)  Braveheart (1995)  \
# 413                     4.0                5.0
# 589                     4.0                4.0
# 473                     4.5                3.0
# 479                     5.0                5.0
# 67                      3.5                2.5
#
# title  Terminator 2: Judgment Day (1991)  Schindler's List (1993)  ...  \
# 413                                  5.0                      4.0  ...
# 589                                  4.5                      5.0  ...
# 473                                  4.0                      5.0  ...
# 479                                  4.5                      5.0  ...
# 67                                   3.5                      4.0  ...
#
# title  Star Wars: Episode VI - Return of the Jedi (1983)  \
# 413                                                  5.0
# 589                                                  4.5
# 473                                                  4.0
# 479                                                  3.5
# 67                                                   5.0
#
# title  Godfather, The (1972)  Fugitive, The (1993)  Batman (1989)  \
# 413                      5.0                   5.0            4.0
# 589                      5.0                   4.0            3.5
# 473                      5.0                   5.0            4.0
# 479                      5.0                   3.5            4.5
# 67                       4.0                   4.5            4.0
#
# title  Saving Private Ryan (1998)  \
# 413                           5.0
# 589                           4.0
# 473                           3.0
# 479                           4.5
# 67                            4.0
#
# title  Lord of the Rings: The Two Towers, The (2002)  \
# 413                                              5.0
# 589                                              5.0
# 473                                              5.0
# 479                                              4.5
# 67                                               4.0
#
# title  Lord of the Rings: The Return of the King, The (2003)  Aladdin (1992)  \
# 413                                                  4.0                 4.0
# 589                                                  4.5                 4.0
# 473                                                  5.0                 4.0
# 479                                                  4.0                 4.0
# 67                                                   4.5                 3.5
#
# title  Fargo (1996)  Sixth Sense, The (1999)
# 413             5.0                      3.0
# 589             4.0                      3.5
# 473             4.0                      5.0
# 479             4.0                      4.0
# 67              2.5                      2.5
#
# [5 rows x 30 columns]

# %%
helper.draw_movies_heatmap(most_rated_movies_users_selection)

# %%
user_movie_ratings =  pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')
most_rated_movies_1k = helper.get_most_rated_movies(user_movie_ratings, 9719)
#most_rated_movies_1k = helper.get_most_rated_movies(user_movie_ratings, 5000)
#most_rated_movies_1k = helper.get_most_rated_movies(user_movie_ratings, 193609)
#most_rated_movies_1k = helper.get_most_rated_movies(user_movie_ratings, 50000)
print(user_movie_ratings.shape)
print(most_rated_movies_1k.shape)
# Out:
# (610, 9719)
# (610, 9719)

# %%
#sparse_ratings = csr_matrix(pd.SparseDataFrame(most_rated_movies_1k).to_coo())
#most_rated_movies_1k.fillna(0)
sp_arr = csr_matrix(most_rated_movies_1k.fillna(0))
sdf = pd.DataFrame.sparse.from_spmatrix(sp_arr)
sparse_ratings = sdf.sparse.to_coo()

# %%
# 20 clusters
#predictions = KMeans(n_clusters=20, algorithm='full').fit_predict(sparse_ratings)
predictions = KMeans(n_clusters=5, algorithm='full').fit_predict(sparse_ratings)

max_users = 70
max_movies = 50

clustered = pd.concat([most_rated_movies_1k.reset_index(), pd.DataFrame({'group':predictions})], axis=1)

# %%
# TODO: Pick a cluster ID from the clusters above
cluster_number = 5

# Let's filter to only see the region of the dataset with the most number of values 
n_users = 75
n_movies = 300
cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)

cluster = helper.sort_by_rating_density(cluster, n_movies, n_users)
helper.draw_movies_heatmap(cluster, axis_labels=False)
# Out:
# C:\Users\User\Documents\GitHub\420_A1\Assignment 1C\Problem_1\helper.py:202: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   heatmap = ax.imshow(most_rated_movies_users_selection,  interpolation='nearest', vmin=0, vmax=5, aspect='auto')

# %%
#cluster = clustered[clustered.group == 5].drop(['index', 'group'], axis=1)
#cluster = helper.sort_by_rating_density(cluster, n_movies, n_users)
#helper.draw_movies_heatmap(cluster, axis_labels=False)

# %%
cluster.fillna('').head()
# Out:
# Empty DataFrame
# Columns: [Forrest Gump (1994), Tomboy (2011), Tom and Jerry: A Nutcracker Tale (2007), Them (Ils) (2006), The Unauthorized Saved by the Bell Story (2014), The Voices (2014), The Void (2016), The Wailing (2016), The Wait (2015), The Wild One (1953), The Witch (2015), The Wolfpack (2015), The Wooden Horse (1950), The Year My Voice Broke (1987), Themroc (1973), The Town that Dreaded Sundown (2014), There Once Was a Dog (1982), Tom and Jerry: Shiver Me Whiskers (2006), Ultimate Avengers 2 (2006), They (2002), Ugly, The (1997), Twinsters (2015), Twister (1990), Two Brothers (Deux frères) (2004), Two Can Play That Game (2001), Two Days, One Night (Deux jours, une nuit) (2014), Two Family House (2000), Umberto D. (1952), Two Much (1995), Two Women (Ciociara, La) (1960), Two for the Money (2005), Tyler Perry's Daddy's Little Girls (2007), Tyler Perry's I Can Do Bad All by Myself (2009), Tyrannosaur (2011), U.S. vs. John Lennon, The (2006), Ugly Duckling and Me!, The (2006), There Will Come a Day (2013), They Call Me Bruce? (a.k.a. A Fistful of Chopsticks) (1982), Twelve O'Clock High (1949), The Rocky Horror Picture Show: Let's Do the Time Warp Again (2016), The Shallows (2016), The Thief (1997), The Shining (1997), The Silence of the Hams (1994), The Space Between Us (2016), The Spirit of Christmas (1995), The Squeeze (2015), The Stanford Prison Experiment (2015), The Star Wars Holiday Special (1978), The Survivalist (2015), The Tale of the Bunny Picnic (1986), The Taming of the Scoundrel (1980), Thin Line Between Love and Hate, A (1996), Thin Man Goes Home, The (1945), Thing: Terror Takes Shape, The (1998), The Runner (2015), The Road Within (2014), They Came Together (2014), The Return of Don Camillo (1953), They Drive by Night (1940), They Might Be Giants (1971), Thief of Bagdad, The (1924), Thief of Bagdad, The (1940), Thief of Paris, The (Le voleur) (1967), The Trust (2016), The Thinning (2016), Tom Segura: Mostly Stories (2016), The Second Renaissance Part II (2003), The Punisher: Dirty Laundry (2012), The Purple Sea (2009), The Putin Interviews (2017), The Quiet Family (1998), The Rabbi's Cat (Le chat du rabbin) (2011), The Red Turtle (2016), Twin Falls Idaho (1999), Twelve Chairs, The (1970), Tiger Raid (2016), Turning Point, The (1977), Tomorrow (2015), Too Big to Fail (2011), Too Funny to Fail: The Life and Death of The Dana Carvey Show (2017), Too Late for Tears (1949), Tooth Fairy 2 (2012), Topaz (1969), Topkapi (1964), Tormented (1960), Torn Curtain (1966), Tornado! (1996), Touch (1997), Trapped (2002), Touch of Pink (2004), Touch of Zen, A (Xia nu) (1971), Touki Bouki (1973), Total Eclipse (1995), Trapped in Paradise (1994), Town is Quiet, The (Ville est tranquille, La) (2000), Travels of an Ant (1983), Trip, The (2002), Trip, The (2010), Trippin' (1999), ...]
# Index: []
#
# [0 rows x 300 columns]

# %%
# TODO: Fill in the name of the column/movie. e.g. 'Forrest Gump (1994)'
# Pick a movie from the table above since we're looking at a subset
#movie_name = 'Apollo 13 (1995)'

#cluster[movie_name].mean()

# %%
# The average rating of 20 movies as rated by the users in the cluster
cluster.mean().head(20)
# Out:
# Forrest Gump (1994)                               NaN
# Tomboy (2011)                                     NaN
# Tom and Jerry: A Nutcracker Tale (2007)           NaN
# Them (Ils) (2006)                                 NaN
# The Unauthorized Saved by the Bell Story (2014)   NaN
# The Voices (2014)                                 NaN
# The Void (2016)                                   NaN
# The Wailing (2016)                                NaN
# The Wait (2015)                                   NaN
# The Wild One (1953)                               NaN
# The Witch (2015)                                  NaN
# The Wolfpack (2015)                               NaN
# The Wooden Horse (1950)                           NaN
# The Year My Voice Broke (1987)                    NaN
# Themroc (1973)                                    NaN
# The Town that Dreaded Sundown (2014)              NaN
# There Once Was a Dog (1982)                       NaN
# Tom and Jerry: Shiver Me Whiskers (2006)          NaN
# Ultimate Avengers 2 (2006)                        NaN
# They (2002)                                       NaN
# dtype: float64

# %%
cluster.fillna('').head()
# Out:
# Empty DataFrame
# Columns: [Forrest Gump (1994), Tomboy (2011), Tom and Jerry: A Nutcracker Tale (2007), Them (Ils) (2006), The Unauthorized Saved by the Bell Story (2014), The Voices (2014), The Void (2016), The Wailing (2016), The Wait (2015), The Wild One (1953), The Witch (2015), The Wolfpack (2015), The Wooden Horse (1950), The Year My Voice Broke (1987), Themroc (1973), The Town that Dreaded Sundown (2014), There Once Was a Dog (1982), Tom and Jerry: Shiver Me Whiskers (2006), Ultimate Avengers 2 (2006), They (2002), Ugly, The (1997), Twinsters (2015), Twister (1990), Two Brothers (Deux frères) (2004), Two Can Play That Game (2001), Two Days, One Night (Deux jours, une nuit) (2014), Two Family House (2000), Umberto D. (1952), Two Much (1995), Two Women (Ciociara, La) (1960), Two for the Money (2005), Tyler Perry's Daddy's Little Girls (2007), Tyler Perry's I Can Do Bad All by Myself (2009), Tyrannosaur (2011), U.S. vs. John Lennon, The (2006), Ugly Duckling and Me!, The (2006), There Will Come a Day (2013), They Call Me Bruce? (a.k.a. A Fistful of Chopsticks) (1982), Twelve O'Clock High (1949), The Rocky Horror Picture Show: Let's Do the Time Warp Again (2016), The Shallows (2016), The Thief (1997), The Shining (1997), The Silence of the Hams (1994), The Space Between Us (2016), The Spirit of Christmas (1995), The Squeeze (2015), The Stanford Prison Experiment (2015), The Star Wars Holiday Special (1978), The Survivalist (2015), The Tale of the Bunny Picnic (1986), The Taming of the Scoundrel (1980), Thin Line Between Love and Hate, A (1996), Thin Man Goes Home, The (1945), Thing: Terror Takes Shape, The (1998), The Runner (2015), The Road Within (2014), They Came Together (2014), The Return of Don Camillo (1953), They Drive by Night (1940), They Might Be Giants (1971), Thief of Bagdad, The (1924), Thief of Bagdad, The (1940), Thief of Paris, The (Le voleur) (1967), The Trust (2016), The Thinning (2016), Tom Segura: Mostly Stories (2016), The Second Renaissance Part II (2003), The Punisher: Dirty Laundry (2012), The Purple Sea (2009), The Putin Interviews (2017), The Quiet Family (1998), The Rabbi's Cat (Le chat du rabbin) (2011), The Red Turtle (2016), Twin Falls Idaho (1999), Twelve Chairs, The (1970), Tiger Raid (2016), Turning Point, The (1977), Tomorrow (2015), Too Big to Fail (2011), Too Funny to Fail: The Life and Death of The Dana Carvey Show (2017), Too Late for Tears (1949), Tooth Fairy 2 (2012), Topaz (1969), Topkapi (1964), Tormented (1960), Torn Curtain (1966), Tornado! (1996), Touch (1997), Trapped (2002), Touch of Pink (2004), Touch of Zen, A (Xia nu) (1971), Touki Bouki (1973), Total Eclipse (1995), Trapped in Paradise (1994), Town is Quiet, The (Ville est tranquille, La) (2000), Travels of an Ant (1983), Trip, The (2002), Trip, The (2010), Trippin' (1999), ...]
# Index: []
#
# [0 rows x 300 columns]

# %%
#user_id = 2

# Get all this user's ratings
#user_2_ratings  = cluster.loc[user_id, :]
#user_2_ratings

# %%
# TODO: Pick a user ID from the dataset
# Look at the table above outputted by the command "cluster.fillna('').head()" 
# and pick one of the user ids (the first column in the table)
#user_id = 4

# Get all this user's ratings
#user_2_ratings  = cluster.loc[user_id, :]

# Which movies did they not rate? (We don't want to recommend movies they've already rated)
#user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]

# What are the ratings of these movies the user did not rate?
#avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]

# Let's sort by rating so the highest rated movies are presented first
#avg_ratings.sort_values(ascending=False)[:20]

# %%
# https://github.com/gouravaich/k-means-clustering-movie-ratings/blob/master/k-means%20Clustering%20of%20Movie%20Ratings.ipynb

# %%
#print(len(avg_ratings.sort_values(ascending=False)))

# %%
#testing

# %%
#predictions 3 
# Pick a cluster ID from the clusters above
#from random import randrange
#cluster_number = randrange(10)
# Let's filter to only see the region of the dataset with the most number of values 
#n_users = 75
#n_movies = 300
#cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)
# Sort and print the cluster
#cluster = helper.sort_by_rating_density(cluster, n_movies, n_users)
#helper.draw_movies_heatmap(cluster, axis_labels=False)

# %%
#print(cluster_number)

# %%
# Print the ratings
#cluster.fillna('').head()

# %%
#movie_name = "Matrix, The (1999)"
#cluster[movie_name].mean()

# %%
# Pick a user ID from the dataset
#user_id = 4
# Get all this user's ratings
#user_2_ratings  = cluster.loc[user_id, :]
# Which movies did they not rate? 
#user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]
# What are the ratings of these movies the user did not rate?
#avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]
# Let's sort by rating so the highest rated movies are presented first
#avg_ratings.sort_values(ascending=False)[:20]

# %%
# Pick a user ID from the dataset
#user_id = 42
# Get all this user's ratings
#user_2_ratings  = cluster.loc[user_id, :]
# Which movies did they not rate? 
#user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]
# What are the ratings of these movies the user did not rate?
#avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]
# Let's sort by rating so the highest rated movies are presented first
#avg_ratings.sort_values(ascending=False)[:20]

# %%
# Pick a user ID from the dataset
#user_id = 314
# Get all this user's ratings
#user_2_ratings  = cluster.loc[user_id, :]
# Which movies did they not rate? 
#user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]
# What are the ratings of these movies the user did not rate?
#avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]
# Let's sort by rating so the highest rated movies are presented first
#avg_ratings.sort_values(ascending=False)[:20]

# %%
from random import randrange
while True: 
    try:
    #predictions testing
        # Pick random cluster ID from the clusters above
        cluster_number = randrange(6)
        #cluster_number = 12
        # Let's filter to only see the region of the dataset with the most number of values 
        n_users = 400
        n_movies = 400
        cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)
        # Sort and print the cluster
        cluster = helper.sort_by_rating_density(cluster, n_movies, n_users)
        helper.draw_movies_heatmap(cluster, axis_labels=False)
        print(cluster_number)
        print("_________")

        # Pick a user ID from the dataset
        user_id = 4
        # Get all this user's ratings
        user_2_ratings  = cluster.loc[user_id, :]
        # Which movies did they not rate? 
        user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]
        # What are the ratings of these movies the user did not rate?
        avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]
        # Let's sort by rating so the highest rated movies are presented first
        User_4_sugest = avg_ratings.sort_values(ascending=False)
        print(User_4_sugest[:20])
        break
    except:
        print("An exception occurred")
# Out:
# C:\Users\User\Documents\GitHub\420_A1\Assignment 1C\Problem_1\helper.py:202: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   heatmap = ax.imshow(most_rated_movies_users_selection,  interpolation='nearest', vmin=0, vmax=5, aspect='auto')
# 5
# _________
# An exception occurred
# 2
# _________
# Godfather, The (1972)                                                             4.500000
# Pulp Fiction (1994)                                                               4.446429
# Usual Suspects, The (1995)                                                        4.404762
# Schindler's List (1993)                                                           4.400000
# Star Wars: Episode VI - Return of the Jedi (1983)                                 4.400000
# Rear Window (1954)                                                                4.392857
# Spirited Away (Sen to Chihiro no kamikakushi) (2001)                              4.388889
# Star Wars: Episode V - The Empire Strikes Back (1980)                             4.387097
# Big Lebowski, The (1998)                                                          4.380952
# Monty Python's Life of Brian (1979)                                               4.375000
# Goodfellas (1990)                                                                 4.361111
# Toy Story 3 (2010)                                                                4.361111
# No Country for Old Men (2007)                                                     4.357143
# Star Wars: Episode IV - A New Hope (1977)                                         4.343750
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    4.310345
# Reservoir Dogs (1992)                                                             4.300000
# Saving Private Ryan (1998)                                                        4.282609
# Trainspotting (1996)                                                              4.266667
# Léon: The Professional (a.k.a. The Professional) (Léon) (1994)                    4.264706
# Shaun of the Dead (2004)                                                          4.250000
# Name: 0, dtype: float64

# %%
while True: 
    try:
    #predictions testing
        # Pick a cluster ID from the clusters above
        cluster_number = randrange(6)
        #cluster_number = 12
        # Let's filter to only see the region of the dataset with the most number of values 
        n_users = 400
        n_movies = 400
        cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)
        # Sort and print the cluster
        cluster = helper.sort_by_rating_density(cluster, n_movies, n_users)
        helper.draw_movies_heatmap(cluster, axis_labels=False)
        print(cluster_number)
        print("_________")

        # Pick a user ID from the dataset
        user_id = 42
        # Get all this user's ratings
        user_2_ratings  = cluster.loc[user_id, :]
        # Which movies did they not rate? 
        user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]
        # What are the ratings of these movies the user did not rate?
        avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]        
        # Let's sort by rating so the highest rated movies are presented first
        User_42_sugest = avg_ratings.sort_values(ascending=False)
        print(User_4_sugest[:20])
        break
    except:
        print("An exception occurred")
# Out:
# 4
# _________
# An exception occurred
# 3
# _________
# Memento (2000)                                           4.365854
# Princess Bride, The (1987)                               4.359649
# Lost in Translation (2003)                               4.342105
# Office Space (1999)                                      4.328571
# Life Is Beautiful (La Vita è bella) (1997)               4.312500
# This Is Spinal Tap (1984)                                4.303571
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)     4.265625
# Brazil (1985)                                            4.250000
# Clockwork Orange, A (1971)                               4.234694
# Dark Knight, The (2008)                                  4.227273
# Wallace & Gromit: The Wrong Trousers (1993)              4.227273
# Kill Bill: Vol. 2 (2004)                                 4.206897
# Full Metal Jacket (1987)                                 4.204545
# Run Lola Run (Lola rennt) (1998)                         4.200000
# Graduate, The (1967)                                     4.178571
# Snatch (2000)                                            4.172414
# Lord of the Rings: The Return of the King, The (2003)    4.146341
# Matrix, The (1999)                                       4.145833
# Jungle Book, The (1967)                                  4.142857
# Army of Darkness (1993)                                  4.136364
# Name: 0, dtype: float64

# %%
i = 0 
while True: 
    try:
    #predictions testing
        # Pick a cluster ID from the clusters above
        cluster_number = randrange(6)
        #cluster_number = i
        #cluster_number = 12
        # Let's filter to only see the region of the dataset with the most number of values 
        n_users = 400
        n_movies = 400
        cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)
        # Sort and print the cluster
        cluster = helper.sort_by_rating_density(cluster, n_movies, n_users)
        helper.draw_movies_heatmap(cluster, axis_labels=False)
        print(cluster_number)
        print("_________")

        # Pick a user ID from the dataset
        user_id = 314
        # Get all this user's ratings
        user_2_ratings  = cluster.loc[user_id, :]
        # Which movies did they not rate? 
        user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]
        # What are the ratings of these movies the user did not rate?
        avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]
        # Let's sort by rating so the highest rated movies are presented first
        User_314_sugest = avg_ratings.sort_values(ascending=False)
        print(User_4_sugest[:20])
        break
    except:
        print("An exception occurred")
    i = i+1
# Out:
# 4
# _________
# An exception occurred
# 2
# _________
# An exception occurred
# 3
# _________
# An exception occurred
# 1
# _________
# Cool Hand Luke (1967)                                                          4.431818
# Shawshank Redemption, The (1994)                                               4.427152
# Lock, Stock & Two Smoking Barrels (1998)                                       4.368421
# To Kill a Mockingbird (1962)                                                   4.304348
# One Flew Over the Cuckoo's Nest (1975)                                         4.285714
# Departed, The (2006)                                                           4.277778
# American History X (1998)                                                      4.272727
# Pulp Fiction (1994)                                                            4.272358
# Green Mile, The (1999)                                                         4.271739
# Rear Window (1954)                                                             4.264706
# Fight Club (1999)                                                              4.255906
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)    4.255814
# Dark Knight, The (2008)                                                        4.247312
# Goodfellas (1990)                                                              4.230000
# Snatch (2000)                                                                  4.228571
# North by Northwest (1959)                                                      4.225000
# Seven Samurai (Shichinin no samurai) (1954)                                    4.222222
# Taxi Driver (1976)                                                             4.222222
# Usual Suspects, The (1995)                                                     4.217647
# Inglourious Basterds (2009)                                                    4.210000
# Name: 0, dtype: float64

# %%
# Calculate error values for all k values we're interested in
#possible_k_values = range(2, 100)
possible_k_values = range(2, 15)
errors_per_k = [helper.clustering_errors(k, sparse_ratings) for k in possible_k_values]
#uses silhouette_score 
fig, ax = plt.subplots(figsize=(16, 6))
plt.plot(possible_k_values, errors_per_k)
plt.xlabel('k values ')
plt.ylabel('Distortion')
# Out:
# Text(0, 0.5, 'Distortion')

# %%
# Calculate error values for all k values we're interested in
possible_k_values = range(2, 100)
#possible_k_values = range(2, 30)
errors_per_k = [helper.clustering_errors(k, sparse_ratings) for k in possible_k_values]
#uses silhouette_score 
fig, ax = plt.subplots(figsize=(16, 6))
plt.plot(possible_k_values, errors_per_k)
plt.xlabel('k values ')
plt.ylabel('Distortion')
# Out:
# Text(0, 0.5, 'Distortion')

# %%
i = 0 
while i<7: 
    try:
    #predictions testing
        # Pick a cluster ID from the clusters above
        cluster_number = i
        #cluster_number = i
        #cluster_number = 12
        # Let's filter to only see the region of the dataset with the most number of values 
        n_users = 400
        n_movies = 400
        cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)
        # Sort and print the cluster
        cluster = helper.sort_by_rating_density(cluster, n_movies, n_users)
        helper.draw_movies_heatmap(cluster, axis_labels=False)
        print(cluster_number)
        print("_________")
    except:
        print("An exception occurred")
    i = i+1
# Out:
# 0
# _________
# 1
# _________
# 2
# _________
# 3
# _________
# 4
# _________
# C:\Users\User\Documents\GitHub\420_A1\Assignment 1C\Problem_1\helper.py:202: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   heatmap = ax.imshow(most_rated_movies_users_selection,  interpolation='nearest', vmin=0, vmax=5, aspect='auto')
# 5
# _________
# C:\Users\User\Documents\GitHub\420_A1\Assignment 1C\Problem_1\helper.py:202: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   heatmap = ax.imshow(most_rated_movies_users_selection,  interpolation='nearest', vmin=0, vmax=5, aspect='auto')
# 6
# _________

# %%
##user 4 most type of viewed movie

# %%
ratings_title = pd.merge(ratings, movies[['movieId', 'title','genres']], on='movieId' )

ratings_title = ratings_title[ratings_title['userId'] == 4]

#ratings_title.sort_values(by=['rating'], ascending=False).head()
ratings_title = ratings_title[ratings_title['rating'] > 3]
#
#ratings_title.head()
ratings_title['genres'].value_counts()
# Out:
# Drama                                      15
# Comedy                                     13
# Comedy|Drama                               10
# Drama|Romance                               6
# Comedy|Drama|Romance                        6
#                                            ..
# Drama|Thriller|War                          1
# Comedy|Drama|Fantasy                        1
# Action|Adventure|Comedy|Fantasy|Romance     1
# Comedy|Drama|Thriller                       1
# Crime|Drama|Film-Noir                       1
# Name: genres, Length: 65, dtype: int64

# %%
#User_4_sugest = pd.merge(User_4_sugest, movies[['genres']], on='movieId' )
#User_4_sugest['genres'].value_counts()

print(User_4_sugest[:5])
# Out:
# Godfather, The (1972)                                4.500000
# Pulp Fiction (1994)                                  4.446429
# Usual Suspects, The (1995)                           4.404762
# Schindler's List (1993)                              4.400000
# Star Wars: Episode VI - Return of the Jedi (1983)    4.400000
# Name: 0, dtype: float64

# %%
#ecommendations = movies[movies['title'] == 'Chinatown (1974)' 
#                         or 'Citizen Kane (1941)' 
#                         or 'Lawrence of Arabia (1962)'
#                         or 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)'
#                         or 'CShawshank Redemption, The (1994)']


recom = movies[movies['title'].isin(['Chinatown (1974)','Citizen Kane (1941)' ])]
recom
# Out:
#      movieId                title                            genres
# 705      923  Citizen Kane (1941)                     Drama|Mystery
# 951     1252     Chinatown (1974)  Crime|Film-Noir|Mystery|Thriller
